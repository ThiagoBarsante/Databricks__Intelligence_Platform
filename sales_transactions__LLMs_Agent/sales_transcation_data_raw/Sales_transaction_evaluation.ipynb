# %%
import pandas as pd

# %%
df = pd.read_csv('./data/raw/sales_transactions.csv', header=0)

date_cols = ['order_date', 'ship_date', 'ingestion_date']
df[date_cols] = df[date_cols].apply(lambda s: pd.to_datetime(s, format='%Y-%m-%d', errors='coerce'))

df.dtypes
# Out:
# transaction_id               int64
# order_date          datetime64[ns]
# ship_date           datetime64[ns]
# customer_id                 object
# customer_age               float64
# gender                      object
# product_id                  object
# product_category            object
# quantity                     int64
# unit_price                 float64
# discount_pct               float64
# city                        object
# state                       object
# payment_type                object
# order_status                object
# ingestion_date      datetime64[ns]
# dtype: object

# %%
df.describe(include='all')
# Out:
#         transaction_id                  order_date  \
# count     100000.00000                      100000
# unique             NaN                         NaN
# top                NaN                         NaN
# freq               NaN                         NaN
# mean       25003.88378  2024-06-30 20:01:25.248000
# min            1.00000         2023-01-01 00:00:00
# 25%        12449.75000         2023-10-01 00:00:00
# 50%        25011.00000         2024-06-30 00:00:00
# 75%        37540.25000         2025-04-02 00:00:00
# max        50000.00000         2026-01-01 00:00:00
# std        14444.83436                         NaN
#
#                          ship_date customer_id  customer_age  gender  \
# count                       100000      100000  74882.000000   79880
# unique                         NaN       78649           NaN       4
# top                            NaN   CUST92214           NaN  Female
# freq                           NaN           7           NaN   20125
# ...

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title='Sales Transactions Data Profiling Report', explorative=True)

# %%
# profile.to_file('./reports/sales_transactions_data_profiling_report.html')

# %%
import os

os.makedirs('./reports', exist_ok=True)
profile.to_file('./reports/sales_transactions_data_profiling_report.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
